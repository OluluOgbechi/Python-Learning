# %% [markdown]
# <a href="https://colab.research.google.com/github/OluluOgbechi/Python-Learning/blob/main/Python_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# I like gaming!
print("N   N   OOO ")
print("NN  N  O   O")
print("N N N  O   O")
print("N  NN  O   O")
print("N   N   OOO")
# Out:
# N   N   OOO
# NN  N  O   O
# N N N  O   O
# N  NN  O   O
# N   N   OOO

# %%
# Create a bmi.py program that calculates your own BMI.
def bmi_calculator(mass, height):
  bmi = mass/(height**2)
  print(bmi)

bmi_calculator(70,1.6)
# Out:
# 27.343749999999996

# %%
# Create a hypotenuse.py program that asks the user for two numbers, a and b, and then calculates the hypotenuse c.
def hypotenuse(a,b):
  c = (a**2 + b**2)**0.5
  print(c)

a=int(input('Enter a: '))
b=int(input('Enter b: '))
c = hypotenuse(a,b)
# Out:
# Enter a: 3
# Enter b: 4
# 5.0

# %%
# Create a currency.py program that asks the user for the amount they have in pesos, soles, and reais and calculates the total in USD.
def tousd(pesos,soles,reais):
  pr = 0.048
  sr = 0.27
  rr = 0.17
  total = (pesos*pr) + (soles*sr) + (reais*rr)
  return total

pesos = int(input("What do you have left in pesos? "))
soles = int(input("What do you have left in soles? "))
reais = int(input("What do you have left in reais? "))

print(tousd(pesos,soles,reais))
# Out:
# What do you have left in pesos? 5600
# What do you have left in soles? 105
# What do you have left in reais? 280
# 344.75000000000006

# %%
# Create a coin_flip.py program: Run 5 times
import random
x = 0
num = random.randint(0, 1)   # Generates a random number that's either 0 or 1

while x < 5:
  x += 1
  if num > 0.5:
    print('Heads')
  else:
    print('Tails')
# Out:
# Tails
# Tails
# Tails
# Tails
# Tails

# %%
# Create a magic8.py program that can respond to any Yes or No questions with a different answer each time it executes.
# Magic 8 Ball: preset responses
import random
def magic_8(question):
  num = random.randint(0,8)

  if num == 8:
    print("Magic 8 Ball: Yes - definitely.")
  elif num == 7:
    print("Magic 8 Ball: It is decidedly so.")
  elif num == 6:
    print("Magic 8 Ball: Without a doubt.")
  elif num == 5:
    print("Magic 8 Ball: Reply hazy, try again.")
  elif num == 4:
    print("Magic 8 Ball: Ask again later.")
  elif num == 3:
    print("Magic 8 Ball: Better not tell you now.")
  elif num == 2:
    print("Magic 8 Ball: My sources say no.")
  elif num == 1:
    print("Magic 8 Ball: Outlook not so good.")
  else:
    print("Magic 8 Ball: Very doubtful.")

question = input("Question: ")
magic_8(question)
# Out:
# Question: Will my bet enter today?
# Magic 8 Ball: Better not tell you now.

# %%
# Write a program that asks the user some questions with the int() and input() functions. Lastly, print out the score for each house. Figure out how to print out the house with the most points!
gryffindor = 0
ravenclaw = 0
hufflepuff = 0
slytherin = 0

question = int(input("Do you like Dawn or Dusk?\n\
1) Dawn\n\
2) Dusk\n\n\
Answer:"))
if question == 1:
  gryffindor = gryffindor + 1
  ravenclaw = ravenclaw + 1
elif question == 2:
  hufflepuff = hufflepuff + 1
  slytherin = slytherin + 1
else:
  print("Wrong input")

question = int(input("\nWhen I’m dead, I want people to remember me as:\n\
1) The Good\n\
2) The Great\n\
3) The Wise\n\
4) The Bold\n\n\
Answer:"))
if question == 1:
  hufflepuff = hufflepuff + 2
elif question == 2:
  slytherin = slytherin + 2
elif question == 3:
  ravenclaw = ravenclaw + 2
elif question == 4:
  gryffindor = gryffindor + 2
else:
  print("Wrong input")

question = int(input("\nWhich kind of instrument most pleases your ear?\n\
1) The violin\n\
2) The trumpet\n\
3) The piano\n\
4) The drum\n\n\
Answer:"))
if question == 1:
  slytherin = slytherin + 4
elif question == 2:
  hufflepuff = hufflepuff + 4
elif question == 3:
  ravenclaw = ravenclaw + 4
elif question == 4:
  gryffindor = gryffindor + 4
else:
  print("Wrong input")

print("\nGryffindor:", gryffindor)
print("Ravenclaw:", ravenclaw)
print("Hufflepuff:", hufflepuff)
print("Slytherin:", slytherin)

if gryffindor > ravenclaw and gryffindor > hufflepuff and gryffindor > slytherin:
  print("\nGryffindor has the most points with", gryffindor, " points.")
elif ravenclaw > gryffindor and ravenclaw > hufflepuff and ravenclaw > slytherin:
  print("\nRavenclaw has the most points with", ravenclaw, " points.")
elif hufflepuff > gryffindor and hufflepuff > ravenclaw and hufflepuff > slytherin:
  print("\nHufflepuff has the most points with", hufflepuff, " points.")
else:
  print("\nSlytherin has the most points at", slytherin, " points.")
# Out:
# Do you like Dawn or Dusk?
# 1) Dawn
# 2) Dusk
#
# Answer:2
#
# When I’m dead, I want people to remember me as:
# 1) The Good
# 2) The Great
# 3) The Wise
# 4) The Bold
#
# Answer:3
#
# Which kind of instrument most pleases your ear?
# 1) The violin
# 2) The trumpet
# 3) The piano
# 4) The drum
#
# Answer:3
#
# Gryffindor: 0
# Ravenclaw: 6
# Hufflepuff: 1
# Slytherin: 1
#
# Ravenclaw has the most points with 6  points.

# %%
# Let's make it so that it's the same guessing game, but there is a new limit to the number of tries (it was infinite before).
guess = 0
tries = 0
while guess != 6 and tries < 5:
  guess = int(input("Guess the number:  "))
  tries += 1

if guess != 6:
  print("You ran out of tries")
else:
  print("You got it!")
# Out:
# Guess the number:  6
# You got it!

# %%
# Create a 99_bottles.py program and use a for loop and a range() function to print out all the verses of "99 Bottles of Beer."
for i in range(1,100):
  i = 100 - i
  print(f"{i} bottles of beer on the wall\n{i} bottles of beer\nTake one down, pass it around\n{i-1} bottles of beer on the wall\n")
# Out:
# 99 bottles of beer on the wall
# 99 bottles of beer
# Take one down, pass it around
# 98 bottles of beer on the wall
#
# 98 bottles of beer on the wall
# 98 bottles of beer
# Take one down, pass it around
# 97 bottles of beer on the wall
#
# 97 bottles of beer on the wall
# 97 bottles of beer
# Take one down, pass it around
# 96 bottles of beer on the wall
#
# 96 bottles of beer on the wall
# 96 bottles of beer
# Take one down, pass it around
# 95 bottles of beer on the wall
#
# 95 bottles of beer on the wall
# 95 bottles of beer
# Take one down, pass it around
# 94 bottles of beer on the wall
#
# 94 bottles of beer on the wall
# 94 bottles of beer
# Take one down, pass it around
# 93 bottles of beer on the wall
#
# 93 bottles of beer on the wall
# 93 bottles of beer
# Take one down, pass it around
# 92 bottles of beer on the wall
#
# 92 bottles of beer on the wall
# 92 bottles of beer
# Take one down, pass it around
# 91 bottles of beer on the wall
#
# ...

# %%
#Create a fizz_buzz.py program that outputs numbers from 1 to 100.
'''Here's the catch:
For multiples of 3, print "Fizz" instead of the number.
For multiples of 5, print "Buzz" instead of the number.
Here's the tricky part: For multiples of 3 and 5, print "FizzBuzz".'''

for i in range(1,100):
  if i % 3 == 0 and i % 5 == 0:
    print("FizzBuzz")
  elif i % 3 == 0 and i % 5 != 0:
    print("Fizz")
  elif 1 % 3 != 0 and i % 5 == 0:
    print("Buzz")
  else:
    print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
